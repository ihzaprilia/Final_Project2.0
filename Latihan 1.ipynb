# %% [markdown]
# ### 1. Data Preparation

# %% [markdown]
# #### a. Import Data

# %%
import pandas as pd
import warnings
import numpy as np
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('6. Student Performance Data.csv')
df.head()
# Out:
#   sex  age  mother_edu  father_edu mother_job father_job  traveltime  \
# 0   F   18           4           4    at_home    teacher           2
# 1   F   17           1           1    at_home      other           1
# 2   F   15           1           1    at_home      other           1
# 3   F   15           4           2     health   services           1
# 4   F   16           3           3      other      other           1
#
#    studytime school_support family_support internet romantic  freetime  \
# 0          2            yes             no       no       no         3
# 1          2             no            yes      yes       no         3
# 2          2            yes             no      yes       no         3
# 3          3             no            yes      yes      yes         2
# 4          2             no            yes       no       no         3
#
#    health  absences  grade
# 0       3         6     30
# 1       3         4     30
# 2       3        10     50
# 3       5         2     75
# 4       5         4     50

# %% [markdown]
# #### b. Data Understanding

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sex             395 non-null    object
#  1   age             395 non-null    int64
#  2   mother_edu      395 non-null    int64
#  3   father_edu      395 non-null    int64
#  4   mother_job      395 non-null    object
#  5   father_job      395 non-null    object
#  6   traveltime      395 non-null    int64
#  7   studytime       395 non-null    int64
#  8   school_support  395 non-null    object
#  9   family_support  395 non-null    object
#  10  internet        395 non-null    object
#  11  romantic        395 non-null    object
#  12  freetime        395 non-null    int64
#  13  health          395 non-null    int64
#  14  absences        395 non-null    int64
#  15  grade           395 non-null    int64
# dtypes: int64(9), object(7)
# memory usage: 49.5+ KB

# %%
numbers = df.select_dtypes(include=['number']).columns
categories = df.select_dtypes(exclude=['number']).columns

# %%
round(df[numbers].describe(),2)
# Out:
#           age  mother_edu  father_edu  traveltime  studytime  freetime  \
# count  395.00      395.00      395.00      395.00     395.00    395.00
# mean    16.70        2.75        2.52        1.45       2.04      3.24
# std      1.28        1.09        1.09        0.70       0.84      1.00
# min     15.00        0.00        0.00        1.00       1.00      1.00
# 25%     16.00        2.00        2.00        1.00       1.00      3.00
# 50%     17.00        3.00        2.00        1.00       2.00      3.00
# 75%     18.00        4.00        3.00        2.00       2.00      4.00
# max     22.00        4.00        4.00        4.00       4.00      5.00
#
#        health  absences   grade
# count  395.00    395.00  395.00
# mean     3.55      5.71   52.08
# std      1.39      8.00   22.91
# min      1.00      0.00    0.00
# 25%      3.00      0.00   40.00
# 50%      4.00      4.00   55.00
# 75%      5.00      8.00   70.00
# max      5.00     75.00  100.00

# %% [markdown]
# #### c. Handle Missing Value & Duplicated

# %%
df.isna().sum()
# Out:
# sex               0
# age               0
# mother_edu        0
# father_edu        0
# mother_job        0
# father_job        0
# traveltime        0
# studytime         0
# school_support    0
# family_support    0
# internet          0
# romantic          0
# freetime          0
# health            0
# absences          0
# grade             0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### d. Feature Engineering

# %%
# Kategorisasi grade
def categorize_grade(grade):
    if grade >= 85:
        return 'A (Excellent)'
    elif grade >= 70:
        return 'B (Good)'
    elif grade >= 52:
        return 'C (Average)'
    elif grade >= 40:
        return 'D (Below Average)'
    else:
        return 'F (Fail)'

df['grade_category'] = df['grade'].apply(categorize_grade)
grade_dist = df['grade_category'].value_counts()

# %%
# Kategori Nilai
def grade_category(x):
    if x < 50:
        return 'Low'
    elif x < 75:
        return 'Medium'
    else:
        return 'High'

df['grade_category'] = df['grade'].apply(grade_category)

# %%
# Study efficiency (waktu belajar vs absensi)
df['study_efficiency'] = df['studytime'] / (df['absences'] + 1)

# %%
# Digital Access Group
df['digital_access'] = np.where(
    df['internet'] == 1,
    'Has Internet',
    'No Internet'
)

# %%
#Risiko Akademik (Early Warning)
df['academic_risk'] = np.where(
    (df['grade'] < 60) & (df['absences'] > 10),
    'High Risk',
    'Low Risk'
)

# %%
df.head()
# Out:
#   sex  age  mother_edu  father_edu mother_job father_job  traveltime  \
# 0   F   18           4           4    at_home    teacher           2
# 1   F   17           1           1    at_home      other           1
# 2   F   15           1           1    at_home      other           1
# 3   F   15           4           2     health   services           1
# 4   F   16           3           3      other      other           1
#
#    studytime school_support family_support internet romantic  freetime  \
# 0          2            yes             no       no       no         3
# 1          2             no            yes      yes       no         3
# 2          2            yes             no      yes       no         3
# 3          3             no            yes      yes      yes         2
# 4          2             no            yes       no       no         3
#
#    health  absences  grade grade_category  study_efficiency digital_access  \
# 0       3         6     30            Low          0.285714    No Internet
# 1       3         4     30            Low          0.400000    No Internet
# 2       3        10     50         Medium          0.181818    No Internet
# 3       5         2     75           High          1.000000    No Internet
# 4       5         4     50         Medium          0.400000    No Internet
#
#   academic_risk
# 0      Low Risk
# 1      Low Risk
# 2      Low Risk
# 3      Low Risk
# 4      Low Risk

# %% [markdown]
# #### e. Save to Excel

# %%
df.to_excel('Student Performance Data.xlsx', index=False)
